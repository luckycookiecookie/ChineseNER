# %% [markdown]
# <a href="https://colab.research.google.com/github/luckycookiecookie/ChineseNER/blob/master/BiLSTM_CRF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls
# Out:
# sample_data

# %%
# !git clone https://github.com/macanv/BERT-BiLSTM-CRF-NER
# Out:
# Cloning into 'BERT-BiLSTM-CRF-NER'...
# remote: Enumerating objects: 335, done.
# remote: Total 335 (delta 0), reused 0 (delta 0), pack-reused 335
# Receiving objects: 100% (335/335), 3.82 MiB | 2.88 MiB/s, done.
# Resolving deltas: 100% (181/181), done.

# %%
import os
os.chdir("BERT-BiLSTM-CRF-NER")

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# creating bert_base.egg-info
# writing bert_base.egg-info/PKG-INFO
# writing dependency_links to bert_base.egg-info/dependency_links.txt
# writing entry points to bert_base.egg-info/entry_points.txt
# writing requirements to bert_base.egg-info/requires.txt
# writing top-level names to bert_base.egg-info/top_level.txt
# writing manifest file 'bert_base.egg-info/SOURCES.txt'
# writing manifest file 'bert_base.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/bert_base
# copying bert_base/__init__.py -> build/lib/bert_base
# creating build/lib/bert_base/client
# copying bert_base/client/__init__.py -> build/lib/bert_base/client
# creating build/lib/bert_base/train
# copying bert_base/train/conlleval.py -> build/lib/bert_base/train
# copying bert_base/train/models.py -> build/lib/bert_base/train
# ...

# %%
# !bert-base-ner-train -help
# Out:
# usage: bert-base-ner-train [-h] [-data_dir DATA_DIR]
#                            [-bert_config_file BERT_CONFIG_FILE]
#                            [-output_dir OUTPUT_DIR]
#                            [-init_checkpoint INIT_CHECKPOINT]
#                            [-vocab_file VOCAB_FILE]
#                            [-max_seq_length MAX_SEQ_LENGTH] [-do_train]
#                            [-do_eval] [-do_predict] [-batch_size BATCH_SIZE]
#                            [-learning_rate LEARNING_RATE]
#                            [-num_train_epochs NUM_TRAIN_EPOCHS]
#                            [-dropout_rate DROPOUT_RATE] [-clip CLIP]
#                            [-warmup_proportion WARMUP_PROPORTION]
#                            [-lstm_size LSTM_SIZE] [-num_layers NUM_LAYERS]
#                            [-cell CELL]
#                            [-save_checkpoints_steps SAVE_CHECKPOINTS_STEPS]
#                            [-save_summary_steps SAVE_SUMMARY_STEPS]
# ...

# %%
# !wget https://storage.googleapis.com/bert_models/2018_11_03/chinese_L-12_H-768_A-12.zip
# !unzip chinese_L-12_H-768_A-12.zip
# Out:
# --2019-05-29 08:34:00--  https://storage.googleapis.com/bert_models/2018_11_03/chinese_L-12_H-768_A-12.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.97.128, 2404:6800:4008:c03::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.97.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 381892918 (364M) [application/zip]
# Saving to: ‘chinese_L-12_H-768_A-12.zip’
#
# chinese_L-12_H-768_ 100%[===================>] 364.20M  55.3MB/s    in 7.6s
#
# 2019-05-29 08:34:09 (48.0 MB/s) - ‘chinese_L-12_H-768_A-12.zip’ saved [381892918/381892918]
#
# Archive:  chinese_L-12_H-768_A-12.zip
#    creating: chinese_L-12_H-768_A-12/
#   inflating: chinese_L-12_H-768_A-12/bert_model.ckpt.meta
#   inflating: chinese_L-12_H-768_A-12/bert_model.ckpt.data-00000-of-00001
#   inflating: chinese_L-12_H-768_A-12/vocab.txt
#   inflating: chinese_L-12_H-768_A-12/bert_model.ckpt.index
# ...

# %%
# !mkdir output

# %%
import os
os.chdir("../")
# !ls
# Out:
# BERT-BiLSTM-CRF-NER  sample_data

# %%
# !pip install bert-base==0.0.7 -i https://pypi.python.org/simple
# Out:
# Looking in indexes: https://pypi.python.org/simple
# ...
#      |████████████████████████████████| 112kB 2.1MB/s
# ...
#   Found existing installation: bert-base 0.0.9
#     Uninstalling bert-base-0.0.9:
#       Successfully uninstalled bert-base-0.0.9
# ...

# %%
# !bert-base-ner-train -help

# %%
import os
os.chdir("BERT-BiLSTM-CRF-NER")
# !ls
# Out:
# bert_base	    chinese_L-12_H-768_A-12	 dist	    requirement.txt
# bert_base.egg-info  chinese_L-12_H-768_A-12.zip  output     run.py
# build		    client_test.py		 pictures   setup.py
# build.sh	    data_process.py		 README.md  terminal_predict.py

# %%
# !python bert_lstm_ner.py --task_name="NER" --do_train=True --do_eval=True   \
                --do_predict=True --data_dir=NERdata --vocab_file=checkpoint/vocab.txt --bert_config_file=checkpoint/bert_config.json --init_checkpoint=checkpoint/bert_model.ckpt   \
                --max_seq_length=128   \
                --train_batch_size=32   \
                --learning_rate=2e-5   \
                --num_train_epochs=3.0   \
                --output_dir=./output/result_dir/

# %%
import os
os.chdir("./content")
# !ls

# %%
# !git clone https://github.com/Determined22/zh-NER-TF.git

# %%
import os
os.chdir("zh-NER-TF")
# !ls
# Out:
# conlleval_rev.pl  data_path_save  eval.py  model.py  README.md
# data_path	  data.py	  main.py  pics      utils.py

# %%
# !python main.py --mode=train
# Out:
# vocab_size: 3905
# Namespace(CRF=True, batch_size=64, clip=5.0, demo_model='1521112368', dropout=0.5, embedding_dim=300, epoch=40, hidden_dim=300, lr=0.001, mode='train', optimizer='Adam', pretrain_embedding='random', shuffle=True, test_data='data_path', train_data='data_path', update_embedding=True)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# ...

# %%
# !python main.py --mode=demo --demo_model=1559122131
# Out:
# vocab_size: 3905
# Namespace(CRF=True, batch_size=64, clip=5.0, demo_model='1559122131', dropout=0.5, embedding_dim=300, epoch=40, hidden_dim=300, lr=0.001, mode='demo', optimizer='Adam', pretrain_embedding='random', shuffle=True, test_data='data_path', train_data='data_path', update_embedding=True)
# ./data_path_save/1559122131/checkpoints/model-31680
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# ...
